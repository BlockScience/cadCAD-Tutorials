# %% [markdown]
# # cadCAD Tutorials: The Robot and the Marbles, Networks Addition
# In [Part 2](https://github.com/BlockScience/SimCAD-Tutorials/blob/master/demos/robot-marbles-part-2/robot-marbles-part-2.ipynb) we introduced the 'language' in which a system must be described in order for it to be interpretable by cadCAD and some of the basic concepts of the library:
# * State Variables
# * Timestep
# * Policies
# * State Update Functions
# * Partial State Update Blocks
# * Simulation Configuration Parameters
#
# In the previous example, we observed how two robotic arms acting in parallel could result in counterintuitive system level behavior despite the simplicity of the individual robotic arm policies.
# In this notebook we'll introduce the concept of networks. This done by extending from two boxes of marbles to *n* boxes which are the nodes in our network. Furthermore, there are are going to be arms between some of the boxes but not others forming a network where the arms are the edges.
#
# __The robot and the marbles__
# * Picture a set of n boxes (`balls`) with an integer number of marbles in each;  a network of robotic arms is capable of taking a marble from their one of their boxes and dropping it into the other one.
# * Each robotic arm in the network only controls 2 boxes and they act by moving a marble from one box to the other.
# * Each robotic arm is programmed to take one marble at a time from the box containing the largest number of marbles and drop it in the other box. It repeats that process until the boxes contain an equal number of marbles.
# * For the purposes of our analysis of this system, suppose we are only interested in monitoring the number of marbles in only their two boxes.

# %%
from cadCAD.engine import ExecutionMode, ExecutionContext, Executor
from cadCAD.configuration import Configuration
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

T = 50 #iterations in our simulation
n=3 #number of boxes in our network
m= 2 #for barabasi graph type number of edges is (n-2)*m

G = nx.barabasi_albert_graph(n, m)
k = len(G.edges)

# %%
balls = np.zeros(n,)

for node in G.nodes:
    rv = np.random.randint(1,25)
    G.nodes[node]['initial_balls'] = rv
    balls[node] = rv

# %%
scale=100
nx.draw_kamada_kawai(G, node_size=balls*scale,labels=nx.get_node_attributes(G,'initial_balls'))

# %%
initial_conditions = {'balls':balls, 'network':G}

# %%
#input the deltas along the edges and update the boxes
#mechanism: edge by node dimensional operator
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# We make the state update functions less "intelligent",
# ie. they simply add the number of marbles specified in _input 
# (which, per the policy function definition, may be negative)


def update_balls(params, step, sL, s, _input):
    
    delta_balls = _input['delta']
    new_balls = s['balls']
    for e in G.edges:
        move_ball = delta_balls[e]
        src = e[0]
        dst = e[1]
        if (new_balls[src] >= move_ball) and (new_balls[dst] >= -move_ball):
            new_balls[src] = new_balls[src]-move_ball
            new_balls[dst] = new_balls[dst]+move_ball
            
    
    key = 'balls'
    value = new_balls
    
    return (key, value)

def update_network(params, step, sL, s, _input):
    
    new_nodes = _input['nodes']
    new_edges = _input['edges']
    new_balls = _input['quantity']
    
    graph = s['network']
    
    for node in new_nodes:
        graph.add_node(node)
        graph.nodes['initial_balls'] = new_balls['quantity']['node']
        graph.nodes[node]['strat'] = _input['node_strats'][node]
        
    for edge in new_edges:
        graph.add_edge(edge[0], edge[1])
        graph.edges[edge]['strat'] = _input['edge_strats'][edge]
    
    
    key = 'network'
    value = graph
    
    return (key, value)

def update_network_balls(params, step, sL, s, _input):
    
    new_nodes = _input['nodes']
    new_balls = _input['quantity']
    
    balls = np.zeros(len(s['balls']+len(new_nodes)))
    
    for node in s['network'].nodes:
        balls = s['balls'][node]
    
    for node in new_nodes:
        balls = new_balls[node]
            
    key = 'balls'
    value = balls
    
    return (key, value)

# %%
# this time lets make three kinds of robots

def greedy_robot(src_balls, dst_balls):
    
    #robot wishes to accumlate balls at its source
    #takes half of its neighbors balls
    if src_balls < dst_balls:
        delta = -np.floor(dst_balls/2)
    else:
        delta = 0
    
    return delta

def fair_robot(src_balls, dst_balls):
    
    #robot follows the simple balancing rule
    delta = np.sign(src_balls-dst_balls)
    
    return delta


def giving_robot(src_balls, dst_balls):
    
    #robot wishes to gice away balls one at a time
    if src_balls > 0:
        delta = 1
    else:
        delta = 0
    
    return delta

# %%
#in the previous version the robots were assigned to the edges
#moving towards an agent based model formulation we assign the stratgies
#instead to the nodes
robot_strategies = [greedy_robot,fair_robot, giving_robot]

for node in G.nodes:
    nstrats = len(robot_strategies)
    rv  = np.random.randint(0,nstrats)
    G.nodes[node]['strat'] = robot_strategies[rv]

for e in G.edges:
    owner_node = e[0]
    G.edges[e]['strat'] = G.nodes[owner_node]['strat']

# %%
#Policy: node by edge dimensional operator
#input the states of the boxes output the deltas along the edges
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# We specify the robotic networks logic in a Policy Function
# unlike previous examples our policy controls a vector valued action, defined over the edges of our network
def robotic_network(params, step, sL, s):
    
    graph = s['network']
    
    
    delta_balls = {}
    for e in graph.edges:
        src = e[0]
        src_balls = s['balls'][src]
        dst = e[1]
        dst_balls = s['balls'][dst]
        
        #transfer balls according to specific robot strat
        srat = graph.edges[e]['strat']
        
        delta_balls[e] = srat(src_balls,dst_balls)
        print(delta_balls)
        
    return_dict = {'nodes': [],'edges': {}, 'quantity': {}, 'node_strats':{},'edge_strats':{},'delta': delta_balls}
    print(return_dict)

    return(return_dict)

# %%
def agent_arrival(params, step, sL, s):
    
    node= len(s['network'].nodes)
    edge_list = s['network'].edges
    
    #choose a m random edges without replacement
    #new = np.random.choose(edgelist,m) 
    new = [(0,0), (1,1)]#tester
    
    nodes = [node]
    edges = [(node,new_node) for new_node in new]
    
    initial_balls = {node:np.random.randint(1,25) }
    
    rv  = np.random.randint(0,nstrats)
    node_strat = {node: robot_strategies[rv]}
    
    edge_strats = {e:node_strat for e in edges}

    return_dict = {'nodes': nodes,
            'edges': edges, 
            'quantity':initial_balls, 
            'node_strats':node_strat,
            'edge_strats':edge_strats,
            'delta': np.zeros(node+1)
           } 
    print(return_dict)
    return(return_dict)

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# In the Partial State Update Blocks, the user specifies if state update functions will be run in series or in parallel
partial_state_update_blocks = [
    { 
        'policies': { # The following policy functions will be evaluated and their returns will be passed to the state update functions
            'robotic_network': robotic_network
        },
        'variables': { # The following state variables will be updated simultaneously
            'balls': update_balls
            
        }
    },
    {
      'policies': { # The following policy functions will be evaluated and their returns will be passed to the state update functions
            'agent_arrival': agent_arrival
        },
        'variables': { # The following state variables will be updated simultaneously
            'network': update_network,
            'balls': update_network_balls
        }
    }
]

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# Settings of general simulation parameters, unrelated to the system itself
# `T` is a range with the number of discrete units of time the simulation will run for;
# `N` is the number of times the simulation will be run (Monte Carlo runs)
# In this example, we'll run the simulation once (N=1) and its duration will be of 10 timesteps
# We'll cover the `M` key in a future article. For now, let's leave it empty
simulation_parameters = {
    'T': range(T),
    'N': 1,
    'M': {}
}

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# The configurations above are then packaged into a `Configuration` object
config = Configuration(initial_state=initial_conditions, #dict containing variable names and initial values
                       partial_state_update_blocks=partial_state_update_blocks, #dict containing state update functions
                       sim_config=simulation_parameters #dict containing simulation parameters
                      )

# %%
exec_mode = ExecutionMode()
exec_context = ExecutionContext(exec_mode.single_proc)
executor = Executor(exec_context, [config]) # Pass the configuration object inside an array
raw_result, tensor = executor.main() # The `main()` method returns a tuple; its first elements contains the raw results
# Out:
# single_proc: [<cadCAD.configuration.Configuration object at 0x1512e1cfd0>]
# {(0, 2): -1.0}
# {(0, 2): -1.0, (1, 2): -12.0}
# {'nodes': [], 'edges': {}, 'quantity': {}, 'node_strats': {}, 'edge_strats': {}, 'delta': {(0, 2): -1.0, (1, 2): -12.0}}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-57ee2d652975> in <module>()
#       2 exec_context = ExecutionContext(exec_mode.single_proc)
#       3 executor = Executor(exec_context, [config]) # Pass the configuration object inside an array
# ----> 4 raw_result, tensor = executor.main() # The `main()` method returns a tuple; its first elements contains the raw results
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/engine/__init__.py in execute(self)
#      96             # ToDO: Deprication Handler - "sanitize" in appropriate place
#      97             tensor_field = create_tensor_field(partial_state_updates.pop(), eps.pop())
# ---> 98             result = self.exec_method(simulation_execs, var_dict_list, states_lists, configs_structs, env_processes_list, Ts, Ns)
#      99             final_result = result, tensor_field
#     100         elif self.exec_context == ExecutionMode.multi_proc:
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/engine/__init__.py in single_proc_exec(simulation_execs, var_dict_list, states_lists, configs_structs, env_processes_list, Ts, Ns)
#      31     l = [simulation_execs, states_lists, configs_structs, env_processes_list, Ts, Ns]
#      32     simulation_exec, states_list, config, env_processes, T, N = list(map(lambda x: x.pop(), l))
# ---> 33     result = simulation_exec(var_dict_list, states_list, config, env_processes, T, N)
#      34     return flatten(result)
#      35
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/engine/simulation.py in simulation(self, var_dict, states_list, configs, env_processes, time_seq, runs)
#     171             TPool().map(
#     172                 lambda run: execute_run(var_dict, states_list, configs, env_processes, time_seq, run),
# --> 173                 list(range(runs))
#     174             )
#     175         )
#
# /anaconda3/lib/python3.6/site-packages/pathos/threading.py in map(self, f, *args, **kwds)
#     132         AbstractWorkerPool._AbstractWorkerPool__map(self, f, *args, **kwds)
#     133         _pool = self._serve()
# --> 134         return _pool.map(star(f), zip(*args)) # chunksize
#     135     map.__doc__ = AbstractWorkerPool.map.__doc__
#     136     def imap(self, f, *args, **kwds):
#
# /anaconda3/lib/python3.6/site-packages/multiprocess/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /anaconda3/lib/python3.6/site-packages/multiprocess/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# /anaconda3/lib/python3.6/site-packages/multiprocess/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# /anaconda3/lib/python3.6/site-packages/multiprocess/pool.py in mapstar(args)
#      42
#      43 def mapstar(args):
# ---> 44     return list(map(*args))
#      45
#      46 def starmapstar(args):
#
# /anaconda3/lib/python3.6/site-packages/pathos/helpers/mp_helper.py in <lambda>(args)
#      13 def starargs(f):
#      14     """decorator to convert a many-arg function to a single-arg function"""
# ---> 15     func = lambda args: f(*args)
#      16    #func.__module__ = f.__module__
#      17    #func.__name__ = f.__name__
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/engine/simulation.py in <lambda>(run)
#     170         pipe_run: List[List[Dict[str, Any]]] = flatten(
#     171             TPool().map(
# --> 172                 lambda run: execute_run(var_dict, states_list, configs, env_processes, time_seq, run),
#     173                 list(range(runs))
#     174             )
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/engine/simulation.py in execute_run(var_dict, states_list, configs, env_processes, time_seq, run)
#     160             run += 1
#     161             states_list_copy: List[Dict[str, Any]] = deepcopy(states_list)
# --> 162             head, *tail = self.run_pipeline(var_dict, states_list_copy, configs, env_processes, time_seq, run)
#     163             del states_list_copy
#     164
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/engine/simulation.py in run_pipeline(self, var_dict, states_list, configs, env_processes, time_seq, run)
#     140         for time_step in time_seq:
#     141             pipe_run: List[Dict[str, Any]] = self.state_update_pipeline(
# --> 142                 var_dict, simulation_list[-1], configs, env_processes, time_step, run
#     143             )
#     144             _, *pipe_run = pipe_run
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/engine/simulation.py in state_update_pipeline(self, var_dict, states_list, configs, env_processes, time_step, run)
#     116             s_conf, p_conf = config[0], config[1]
#     117             states_list: List[Dict[str, Any]] = self.partial_state_update(
# --> 118                 var_dict, sub_step, states_list, s_conf, p_conf, env_processes, time_step, run
#     119             )
#     120
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/engine/simulation.py in partial_state_update(self, var_dict, sub_step, sL, state_funcs, policy_funcs, env_processes, time_step, run)
#      70         last_in_obj: Dict[str, Any] = sL[-1]
#      71
# ---> 72         _input: Dict[str, Any] = self.policy_update_exception(self.get_policy_input(var_dict, sub_step, sL, last_in_obj, policy_funcs))
#      73
#      74         # ToDo: add env_proc generator to `last_in_copy` iterator as wrapper function
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/engine/simulation.py in get_policy_input(self, var_dict, sub_step, sL, s, funcs)
#      39             return list(map(lambda f: f(var_dict, sub_step, sL, s), funcs))
#      40
# ---> 41         return foldr(call, get_col_results(var_dict, sub_step, sL, s, funcs))(ops)
#      42
#      43     def apply_env_proc(
#
# /anaconda3/lib/python3.6/site-packages/fn/op.py in fold(it)
#      69         args = [flip(f), reversed(it)]
#      70         if init is not None: args.append(init)
# ---> 71         return reduce(*args)
#      72
#      73     return fold
#
# /anaconda3/lib/python3.6/site-packages/fn/op.py in _flipper(a, b)
#      24
#      25     def _flipper(a, b):
# ---> 26         return f(b, a)
#      27
#      28     setattr(_flipper, "__flipback__", f)
#
# /anaconda3/lib/python3.6/site-packages/fn/op.py in call(f, *args, **kwargs)
#       9
#      10 def call(f, *args, **kwargs):
# ---> 11     return f(*args, **kwargs)
#      12
#      13 def flip(f):
#
# /anaconda3/lib/python3.6/site-packages/fn/op.py in fold(it)
#      69         args = [flip(f), reversed(it)]
#      70         if init is not None: args.append(init)
# ---> 71         return reduce(*args)
#      72
#      73     return fold
#
# /anaconda3/lib/python3.6/site-packages/fn/op.py in _flipper(a, b)
#      24
#      25     def _flipper(a, b):
# ---> 26         return f(b, a)
#      27
#      28     setattr(_flipper, "__flipback__", f)
#
# /anaconda3/lib/python3.6/site-packages/fn/func.py in _curried(*args, **kwargs)
#      79
#      80         if count == len(spec.args) - len(args):
# ---> 81             return func(*args, **kwargs)
#      82
#      83         return curried(partial(func, *args, **kwargs))
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/configuration/utils/policyAggregation.py in dict_op(f, d1, d2)
#      40     key_set = set(list(d1.keys()) + list(d2.keys()))
#      41
# ---> 42     return {k: f(set_base_value(d1, d2, k), set_base_value(d2, d1, k)) for k in key_set}
#      43
#      44
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/configuration/utils/policyAggregation.py in <dictcomp>(.0)
#      40     key_set = set(list(d1.keys()) + list(d2.keys()))
#      41
# ---> 42     return {k: f(set_base_value(d1, d2, k), set_base_value(d2, d1, k)) for k in key_set}
#      43
#      44
#
# /anaconda3/lib/python3.6/site-packages/cadCAD/configuration/utils/policyAggregation.py in <lambda>(a, b)
#      18
#      19
# ---> 20 add = lambda a, b: a + b
#      21
#      22
#
# TypeError: unsupported operand type(s) for +: 'int' and 'dict'

# %%
df = pd.DataFrame(raw_result)
balls_list = [b for b in df.balls]

# %%
plt.plot(df.timestep.values, balls_list)
plt.xlabel('iteration')
plt.ylabel('number of balls')
plt.title('balls in each box')
plt.legend(['Box #'+str(node) for node in range(n)], ncol = 2)

# %%
end_state_balls = np.array([b for b in balls_list[-1]])
avg_balls = np.array([np.mean(b) for b in balls_list])

for node in G.nodes:
    G.nodes[node]['final_balls'] = end_state_balls[node]
    G.nodes[node]['avg_balls'] = avg_balls[node]

# %%
cmap = plt.cm.jet
Nc = cmap.N
Ns = len(robot_strategies)
d = int(Nc/Ns)

k = len(G.edges)
strat_color = []
for e in G.edges:
    
    for i in range(Ns):
        if G.edges[e]['strat']==robot_strategies[i]:
            color = cmap(i*d)
            G.edges[e]['color'] = color
            strat_color = strat_color+[color]

# %%
nx.draw_kamada_kawai(G, node_size=end_state_balls*scale, labels=nx.get_node_attributes(G,'final_balls'), edge_color=strat_color)
print(end_state_balls)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1b471e0de58b> in <module>()
# ----> 1 nx.draw_kamada_kawai(G, node_size=end_state_balls*scale, labels=nx.get_node_attributes(G,'final_balls'), edge_color=strat_color)
#       2 print(end_state_balls)
#
# NameError: name 'end_state_balls' is not defined

# %%
rolling_avg_balls = np.zeros((T+1, n))
for t in range(T+1):
    for node in G.nodes:
        for tau in range(t):
            rolling_avg_balls[t,node] = (tau)/(tau+1)*rolling_avg_balls[t, node]+ 1/(tau+1)*balls_list[tau][node]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f69dc3a84685> in <module>()
#       3     for node in G.nodes:
#       4         for tau in range(t):
# ----> 5             rolling_avg_balls[t,node] = (tau)/(tau+1)*rolling_avg_balls[t, node]+ 1/(tau+1)*balls_list[tau][node]
#
# NameError: name 'balls_list' is not defined

# %%
plt.plot(range(len(rolling_avg_balls)),rolling_avg_balls)
plt.xlabel('iteration')
plt.ylabel('number of balls')
plt.title('time average balls in each box')
plt.legend(['Box #'+str(node) for node in range(n)], ncol = 2)

# %%
for node in G.nodes:
    G.nodes[node]['avg_balls'] = int(10*(rolling_avg_balls[node][-1]))/10

nx.draw_kamada_kawai(G, node_size=avg_balls*scale, labels=nx.get_node_attributes(G,'avg_balls'))
print(end_state_balls)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-868d861cd23c> in <module>()
#       2     G.nodes[node]['avg_balls'] = int(10*(rolling_avg_balls[node][-1]))/10
#       3
# ----> 4 nx.draw_kamada_kawai(G, node_size=avg_balls*scale, labels=nx.get_node_attributes(G,'avg_balls'))
#       5 print(end_state_balls)
#
# NameError: name 'avg_balls' is not defined

# %%
cmap = plt.cm.jet
Nc = cmap.N
Nt = len(simulation_parameters['T'])
dN = int(Nc/Nt)
cmaplist = [cmap(i*dN) for i in range(Nt)]

for t in simulation_parameters['T']:
    state = np.array([b for b in balls_list[t]])
    nx.draw_kamada_kawai(G, node_size=state*scale, alpha = .4/(t+1), node_color = cmaplist[t])
